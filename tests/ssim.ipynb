# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import transform
from skimage.metrics import structural_similarity as ssim

# %%
init_pic = np.load("init_pic.npy")
pic=np.load("pic.npy")

# %%
plt.imshow(init_pic)

# %%
plt.imshow(pic)

# %%
# init_pic= color.rgb2gray(init_pic)
# pic = color.rgb2gray(pic)
type=pic.dtype
init_pic=transform.resize(init_pic,(100,100,3),preserve_range=True).astype(type)
pic=transform.resize(pic,(100,100,3),preserve_range=True).astype(type)
# init_pic=transform.resize(init_pic,(init_pic.shape[0]/4,init_pic.shape[1]/4),preserve_range=True).astype(type)
# pic=transform.resize(pic,(pic.shape[0]/4,pic.shape[1]/4),preserve_range=True).astype(type)

# %%
ssim(init_pic,pic,channel_axis=2)
# Out:
# 0.9760456048259663
